# %%
def guarantee_win(self, game_state):
    if game_state.bankroll > game_state.round_num * 1.5:
        return FoldAction()

# %%
with open("bankroll.txt", "a") as f:
    f.write(str(game_state.bankroll) + "\n")

# %%
    with open("bankroll.txt", "w") as f:
        f.write("")

# %%
import numpy as np
import matplotlib.pyplot as plt


with open("bankroll.txt", "r") as f:
    L3 = f.read()

bankrolls = np.array(L3.strip().split("\n")).astype(int)

plt.plot(bankrolls)
plt.show()
